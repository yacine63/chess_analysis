# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px

import pandas as pd
import matplotlib.pyplot as plt

import fonctions
import preprocessing_steps
import stats

# %%
games_df = pd.read_csv("yacine_games.csv") ; games_df.head(3)
# Out:
#          date     white white elo        black black elo resultat  ECO  \
# 0  2020.10.03  Simakoff      2177     yacine63      2162      0-1  C06
# 1  2020.10.03  yacine63      2158  Du_Verloren      2081      1-0  E01
# 2  2020.10.03  yacine63      2153  tillubombay      2091      1-0  D20
#
#    perf white  perf black                                              moves
# 0        -5.0         6.0   e2e4 e7e6 d2d4 d7d5 b1d2 g8f6 e4e5 f6d7 f1d3 ...
# 1         4.0        -4.0   d2d4 g8f6 c2c4 e7e6 g2g3 d7d5 f1g2 f8b4 c1d2 ...
# 2         5.0        -5.0   d2d4 d7d5 c2c4 d5c4 e2e3 e7e5 f1c4 e5d4 g1f3 ...

# %%
games_df = preprocessing_steps.preprocess(games_df) ; games_df.head(3)
# Out:
#         date     white white elo        black black elo resultat  ECO  \
# 0 2020-10-03  Simakoff      2177     yacine63      2162      0-1  C06
# 1 2020-10-03  yacine63      2158  Du_Verloren      2081      1-0  E01
# 2 2020-10-03  yacine63      2153  tillubombay      2091      1-0  D20
#
#   perf white perf black                                              moves  \
# 0       -5.0        6.0   e2e4 e7e6 d2d4 d7d5 b1d2 g8f6 e4e5 f6d7 f1d3 ...
# 1        4.0       -4.0   d2d4 g8f6 c2c4 e7e6 g2g3 d7d5 f1g2 f8b4 c1d2 ...
# 2        5.0       -5.0   d2d4 d7d5 c2c4 d5c4 e2e3 e7e5 f1c4 e5d4 g1f3 ...
#
#           opening           variation  year  nb
# 0          French  Tarrasch Variation  2020   1
# 1  Queen's Indian            Catalane  2020   1
# 2  Queen's Gambit                 QGA  2020   1

# %%
white = games_df[games_df["white"]=="yacine63"]
black = games_df[games_df["black"]=="yacine63"]
fig = px.bar(white, x="opening", color="resultat", barmode="group", title="Yacine's perfomance with white")
fig
# Out:
# <div>
#
#
#             <div id="03e32a5f-fbfb-4066-aec0-b7896b9f8a44" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03e32a5f-fbfb-4066-aec0-b7896b9f8a44")) {
#                     Plotly.newPlot(
#                         '03e32a5f-fbfb-4066-aec0-b7896b9f8a44',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "resultat=1-0<br>opening=%{x}", "legendgroup": "1-0", "marker": {"color": "#636efa"}, "name": "1-0", "offsetgroup": "1-0", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Queen's Indian", "Queen's Gambit", "Irregular", "Irregular", "Trompowsky", "Benoni defense", "Trompowsky", "Queen's Gambit", "Benoni defense", "Queen's Gambit", "Benoni defense", "English
ambit", "Grunfeld Defence", "Queen's Indian", "Queen's Indian", "Trompowsky", "English Opening", "Trompowsky", "Queen's Indian", "Queen's Gambit", "Queen's Indian", "Benoni defense", "King's Indian", "Trompowsky", "Trompowsky", "King's Indian", "Queen's Gambit", "King's Indian", "Queen's Gambit", "Queen's Indian", "Queen's Indian", "King's Indian", "Queen's Gambit", "King's Indian", "Benoni defense", "King's Indian", "Queen's Gambit", "King's Indian", "Benoni defense", "Queen's Indian", "Queen's Indian", "English Opening", "King's Indian", "King's Indian", "King's Indian", "King's Indian", "Benoni defense", "Queen's Indian", "Queen's Gambit", "Queen's Indian", "Queen's Gambit", "Queen's Indian", "Queen's Indian", "Benoni defense", "English Opening", "Dutch", "Grunfeld Defence", "English Opening", "King's Indian", "English Ope ...

# %%
# %tb

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
app.run_server(mode="jupyterlab")
app.layout = html.Div(children=[
    html.H1(children='Hello Dash'),

    html.Div(children='''
        Dash: A web application framework for Python.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-22-6feec0701ed9> in <module>
#      18
#      19 if __name__ == '__main__':
# ---> 20     app.run_server(debug=True)
#
# ~\Anaconda3\envs\env\lib\site-packages\dash\dash.py in run_server(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    1710             self.logger.info("Dash is running on %s://%s%s%s\n", *display_url)
#    1711
# -> 1712         self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# c:\users\yacin\anaconda3\lib\site-packages\flask\app.py in run(self, host, port, debug, load_dotenv, **options)
#     988
#     989         try:
# --> 990             run_simple(host, port, self, **options)
#     991         finally:
#     992             # reset the first request information if the development server
#
# c:\users\yacin\anaconda3\lib\site-packages\werkzeug\serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#    1048         from ._reloader import run_with_reloader
#    1049
# -> 1050         run_with_reloader(inner, extra_files, reloader_interval, reloader_type)
#    1051     else:
#    1052         inner()
#
# c:\users\yacin\anaconda3\lib\site-packages\werkzeug\_reloader.py in run_with_reloader(main_func, extra_files, interval, reloader_type)
#     337             reloader.run()
#     338         else:
# --> 339             sys.exit(reloader.restart_with_reloader())
#     340     except KeyboardInterrupt:
#     341         pass
#
# SystemExit: 1
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-9ad901929a75> in <module>
#       4
#       5 app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
# ----> 6 app.run_server(mode="jupyterlab")
#       7 app.layout = html.Div(children=[
#       8     html.H1(children='Hello Dash'),
#
# ~\Anaconda3\envs\env\lib\site-packages\dash\dash.py in run_server(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    1710             self.logger.info("Dash is running on %s://%s%s%s\n", *display_url)
#    1711
# -> 1712         self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# c:\users\yacin\anaconda3\lib\site-packages\flask\app.py in run(self, host, port, debug, load_dotenv, **options)
#     988
#     989         try:
# --> 990             run_simple(host, port, self, **options)
#     991         finally:
#     992             # reset the first request information if the development server
#
# TypeError: run_simple() got an unexpected keyword argument 'mode'
